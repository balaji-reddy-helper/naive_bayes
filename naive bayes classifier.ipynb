# %% [markdown]
# ## *Importing data set using pandas*

# %%
import pandas as pd
data=pd.read_csv(r'/home/balu/Desktop/DA/ml/play_tennis.csv')
data.head(10)
# Out:
#    day   outlook  temp humidity    wind play
# 0   D1     Sunny   Hot     High    Weak   No
# 1   D2     Sunny   Hot     High  Strong   No
# 2   D3  Overcast   Hot     High    Weak  Yes
# 3   D4      Rain  Mild     High    Weak  Yes
# 4   D5      Rain  Cool   Normal    Weak  Yes
# 5   D6      Rain  Cool   Normal  Strong   No
# 6   D7  Overcast  Cool   Normal  Strong  Yes
# 7   D8     Sunny  Mild     High    Weak   No
# 8   D9     Sunny  Cool   Normal    Weak  Yes
# 9  D10      Rain  Mild   Normal    Weak  Yes

# %%
data.describe()
# Out:
#        day outlook  temp humidity  wind play
# count   14      14    14       14    14   14
# unique  14       3     3        2     2    2
# top     D1   Sunny  Mild     High  Weak  Yes
# freq     1       5     6        7     8    9

# %%
print(data.ndim)
print(data.shape)
print(data.size)
# Out:
# 2
# (14, 6)
# 84

# %%
data=data.drop(axis=1,columns=["day"])
print(data)
# Out:
#      outlook  temp humidity    wind play
# 0      Sunny   Hot     High    Weak   No
# 1      Sunny   Hot     High  Strong   No
# 2   Overcast   Hot     High    Weak  Yes
# 3       Rain  Mild     High    Weak  Yes
# 4       Rain  Cool   Normal    Weak  Yes
# 5       Rain  Cool   Normal  Strong   No
# 6   Overcast  Cool   Normal  Strong  Yes
# 7      Sunny  Mild     High    Weak   No
# 8      Sunny  Cool   Normal    Weak  Yes
# 9       Rain  Mild   Normal    Weak  Yes
# 10     Sunny  Mild   Normal  Strong  Yes
# 11  Overcast  Mild     High  Strong  Yes
# 12  Overcast   Hot   Normal    Weak  Yes
# 13      Rain  Mild     High  Strong   No

# %% [markdown]
# ## *Training Model*

# %%
d={"Yes":{"outlook":{},"temp":{},"humidity":{},"wind":{}},"No":{"outlook":{},"temp":{},"humidity":{},"wind":{}}}
#prior probabilities
prob_of_play_yes=(data.play.str.count("Yes").sum())/data["play"].count()
prob_of_play_no=(data.play.str.count("No").sum())/data["play"].count()
#posteiriory probabilities
c=0
for i,j in zip(data["outlook"].str.count("Sunny"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_outlook_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["outlook"]["Sunny"]=prob_of_outlook_yes

c=0
for i,j in zip(data["outlook"].str.count("Overcast"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_outlook_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["outlook"]["Overcast"]=prob_of_outlook_yes

c=0
for i,j in zip(data["outlook"].str.count("Rain"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_outlook_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["outlook"]["Rain"]=prob_of_outlook_yes

c=0
for i,j in zip(data["temp"].str.count("Hot"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_temp_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["temp"]["Hot"]=prob_of_temp_yes

c=0
for i,j in zip(data["temp"].str.count("Mild"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_temp_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["temp"]["Mild"]=prob_of_temp_yes

c=0
for i,j in zip(data["temp"].str.count("Cool"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_temp_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["temp"]["Cool"]=prob_of_temp_yes

c=0
for i,j in zip(data["humidity"].str.count("High"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_humidity_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["humidity"]["High"]=prob_of_humidity_yes

c=0
for i,j in zip(data["humidity"].str.count("Normal"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_humidity_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["humidity"]["Normal"]=prob_of_humidity_yes

c=0
for i,j in zip(data["wind"].str.count("Weak"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_wind_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["wind"]["Weak"]=prob_of_wind_yes

c=0
for i,j in zip(data["wind"].str.count("Strong"),data["play"].str.count("Yes")):
    if(i==j and j==1):
        c=c+1
prob_of_wind_yes=c/data["play"].str.count("Yes").sum()
d["Yes"]["wind"]["Strong"]=prob_of_wind_yes

c=0
for i,j in zip(data["outlook"].str.count("Sunny"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_outlook_no=c/data["play"].str.count("No").sum()
d["No"]["outlook"]["Sunny"]=prob_of_outlook_no

c=0
for i,j in zip(data["outlook"].str.count("Overcast"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_outlook_no=c/data["play"].str.count("No").sum()
d["No"]["outlook"]["Overcast"]=prob_of_outlook_no

c=0
for i,j in zip(data["outlook"].str.count("Rain"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_outlook_no=c/data["play"].str.count("No").sum()
d["No"]["outlook"]["Rain"]=prob_of_outlook_no

c=0
for i,j in zip(data["temp"].str.count("Hot"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_temp_no=c/data["play"].str.count("No").sum()
d["No"]["temp"]["Hot"]=prob_of_temp_no

c=0
for i,j in zip(data["temp"].str.count("Mild"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_temp_no=c/data["play"].str.count("No").sum()
d["No"]["temp"]["Mild"]=prob_of_temp_no

c=0
for i,j in zip(data["temp"].str.count("Cool"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_temp_no=c/data["play"].str.count("No").sum()
d["No"]["temp"]["Cool"]=prob_of_temp_no

c=0
for i,j in zip(data["humidity"].str.count("High"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_humidity_no=c/data["play"].str.count("No").sum()
d["No"]["humidity"]["High"]=prob_of_humidity_no

c=0
for i,j in zip(data["humidity"].str.count("Normal"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_humidity_no=c/data["play"].str.count("No").sum()
d["No"]["humidity"]["Normal"]=prob_of_humidity_no

c=0
for i,j in zip(data["wind"].str.count("Weak"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_wind_no=c/data["play"].str.count("No").sum()
d["No"]["wind"]["Weak"]=prob_of_wind_no

c=0
for i,j in zip(data["wind"].str.count("Strong"),data["play"].str.count("No")):
    if(i==j and j==1):
        c=c+1
prob_of_wind_no=c/data["play"].str.count("No").sum()
d["No"]["wind"]["Strong"]=prob_of_wind_no

# %% [markdown]
# ## *Testing the Model*

# %%
test_data_features={"outlook":["Sunny","Overcast","Rain","Overcast"],"temp":["Hot","Mild","Cool","Cool"],"humidity":["High","Normal","Normal","Normal"],"wind":["Weak","Weak","Strong","Strong"]}
indict=pd.DataFrame.from_dict(test_data_features)
test_data_play=["No","Yes","No","Yes"]
response_of_model_on_testdata=[]
for i,row in indict.iterrows():
    prob_of_yes_given_testdata=d["Yes"]["outlook"][row["outlook"]]*d["Yes"]["temp"][row["temp"]]*d["Yes"]["humidity"][row["humidity"]]*d["Yes"]["wind"][row["wind"]]
    prob_of_yes_given_testdata=(prob_of_yes_given_testdata)*(prob_of_play_yes)
    
    prob_of_no_given_testdata=d["No"]["outlook"][row["outlook"]]*d["No"]["temp"][row["temp"]]*d["No"]["humidity"][row["humidity"]]*d["No"]["wind"][row["wind"]]
    prob_of_no_given_testdata=(prob_of_no_given_testdata)*(prob_of_play_no)
    
    if(prob_of_yes_given_testdata >= prob_of_no_given_testdata):
        response_of_model_on_testdata.append("Yes")
    else:
        response_of_model_on_testdata.append("No")

# %% [markdown]
# ## *Finding accuracy of model*

# %%
n=len(test_data_play)
c=0
for i,j in zip(test_data_play,response_of_model_on_testdata):
    if((i=="Yes" and j=="Yes") or(i=="No" and j=="No")):
        c=c+1
accuracy=c/n
print(accuracy)
# Out:
# 0.75
